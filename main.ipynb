# %% [markdown]
# ## Importing Package

# %%
from Linkdin.linkdin_jobs_scraping import linkdin_jobs_scraping
from Linkdin.constant import *
import pandas

# %% [markdown]
# ## Initailizing object

# %%
data,ids = None,None
ls = linkdin_jobs_scraping()

# %% [markdown]
# ## Login to Linkdin using my credientials

# %%
ls.Login(email=my_email,password=password,login_page_link=login_page)
# Out:
# Login successful!
# True

# %% [markdown]
# ## load jobs for Data Science in Pakistan

# %%
ls.load_job_page(URL=jobs_page)

# %% [markdown]
# ## Get ids of all (n pages) jobs posted for Data Science

# %%
ids = ls.load_Ids_of_all_jobs()
# Out:
# Scrolling...
# Scrolling...
# Scrolling...
# Scrolling...
# Scrolling...
# Scrolling...
# Scrolling...
# Scrolling...
# Scrolling...
# Scrolling...
# Scrolling...
# Scrolling...
# Scrolling...
# Scrolling...
# Scrolling...
# Scrolling...
# Scrolling...
# Scrolling...
# Scrolling...
# Scrolling...
# Reached the last page.

# %%
print(f'{len(ids)} jobs found tagging data Science in Pakistan')
# Out:
# 500 jobs found tagging data Science in Pakistan

# %% [markdown]
# ## Fetching Jobs

# %%
data = ls.get_details_of_jobs(ids,job_details_page)
# Out:
# getting details of page 0
# getting details of page 1
# getting details of page 2
# getting details of page 3
# getting details of page 4
# getting details of page 5
# getting details of page 6
# getting details of page 7
# getting details of page 8
# getting details of page 9
# getting details of page 10
# getting details of page 11
# getting details of page 12
# getting details of page 13
# getting details of page 14
# getting details of page 15
# getting details of page 16
# getting details of page 17
# getting details of page 18
# getting details of page 19
# getting details of page 20
# getting details of page 21
# getting details of page 22
# getting details of page 23
# getting details of page 24
# getting details of page 25
# getting details of page 26
# getting details of page 27
# getting details of page 28
# getting details of page 29
# getting details of page 30
# getting details of page 31
# getting details of page 32
# getting details of page 33
# ...

# %%
print(f'total job fetched {len(data)}')
# Out:
# total job fetched 492

# %%
ls.end()
# Out:
# Closing the browser

# %%
pandas.DataFrame(data).to_csv('data_science_jobs_in_Pakistan.csv',index=False)
